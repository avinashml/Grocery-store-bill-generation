# %%
from datetime import datetime

name=input("Enter your name:")

lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
print(lists)
# Out:
# Enter your name:Avinash
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
print(price)
# Out:
# Enter your name:Avinash
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:Salt
# Enter quantity:3
# if you want to buy press1 or 2 to exit:2
# 0

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            for i in range(len(pricelist)):
                print(i,ilist[i],qlist[i],plist[i])
# Out:
# Enter your name:ashu
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:sugar
# Enter quantity:4
# can i print you bill yes or no:yes
# 0 sugar 4 160
# if you want to buy press1 or 2 to exit:1
# Enter your items:coffee
# Enter quantity:2
# Sorry the entered item is not available
# can i print you bill yes or no:yes
# 0 sugar 4 160
# if you want to buy press1 or 2 to exit:2

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print("Name:",name30*" ","Date:",datetime.now())
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalprice)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
# Enter your name:Avinash
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:Ghee
# Enter quantity:3
# can i print you bill yes or no:yes
# ========================= More store =========================
#                              Hyderabad
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2544/3156041438.py in <module>
#      64             print(25*"=","More store",25*"=")
#      65             print(28*" ","Hyderabad")
# ---> 66             print("Name:",name30*" ","Date:",datetime.now())
# ...

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],8*' 'plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalprice)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_2544/4205006112.py", line 69
#     print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],8*' 'plist[i])
#                                                      ^
# SyntaxError: invalid syntax

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print("Name:",name30*" ","Date:",datetime.now())
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],8*' 'plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalprice)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp/ipykernel_2544/2931230829.py", line 70
#     print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],8*' 'plist[i])
#                                                      ^
# SyntaxError: invalid syntax

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print("Name:",name30*" ","Date:",datetime.now())
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalprice)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
# Enter your name:ashu
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:rice
# Enter quantity:3
# can i print you bill yes or no:yes
# ========================= More store =========================
#                              Hyderabad
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2544/3156041438.py in <module>
#      64             print(25*"=","More store",25*"=")
#      65             print(28*" ","Hyderabad")
# ---> 66             print("Name:",name30*" ","Date:",datetime.now())
# ...

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print("Name:",name,30*" ","Date:",datetime.now())
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalamount)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
# Enter your name:avinash
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:Tea
# Enter quantity:2
# can i print you bill yes or no:yes
# ========================= More store =========================
#                              Hyderabad
# Name: avinash                                Date: 2022-02-28 11:13:43.468198
# ---------------------------------------------------------------------------
# sno          items          quantity     price
# 0                   Tea     2 1500
# ---------------------------------------------------------------------------
#                                                    totalamount: Rs 1500
# ...

# %%
from datetime import datetime

name=input("Enter your name:")
#List of items
lists='''Rice Rs 50/kg
Sugar            Rs 40/kg
Salt             Rs 20/kg
Dal              Rs 100/kg
Coffee           Rs 1000/kg
Tea              Rs 750/kg
Groundnut Oil    Rs 150/litre
Paneer           Rs 350/kg
Boost            Rs 150/kg
Ghee             Rs 350/kg
Colgate          Rs 200/gms
'''
price=0
pricelist=[]
totalprice=0
Finalfinalprice=0
ilist=[]
qlist=[]
plist=[]

#rates for items
items={'rice':50,
       'sugar':40,
       'salt':20,
       'Dal':100, 
       'Coffee':1000,
       'Tea':750,
       'Groundnut oil': 150,
       'Paneer':350,
       'Boost':150,
       'Ghee':350,
       'Colgate':200}
option=int(input("for list of items press 1"))
if option==1:
    print(lists)
for i in range(len(items)):
    inp1=int(input("if you want to buy press1 or 2 to exit:"))
    if inp1==2:
        break
    if inp1==1:
        item=input("Enter your items:")
        quantity=int(input("Enter quantity:"))
        if item in items.keys():
            price=quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice+=price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst=(totalprice*5)/100
            finalamount=gst+totalprice
        else:
            print("Sorry the entered item is not available")
    else:
        print("you have entered wrong number")
    inp=input("can i print you bill yes or no:")
    if inp=='yes':
        pass
        if finalamount!=0:
            print(25*"=","More store",25*"=")
            print(28*" ","Hyderabad")
            print("Name:",name,30*" ","Date:",datetime.now())
            print(75*"-")
            print("sno",8*" ",'items',8*" ",'quantity',3*" ",'price')
            for i in range(len(pricelist)):
                print(i,8*' ',8*' ',ilist[i],3*' ',qlist[i],plist[i])
            print(75*'-')
            print(50*" ",'totalamount:','Rs',totalprice)
            print("gst amount",50*" ",'totalamount:','Rs',gst)
            print(75*"-")
            print(50*" ",'finalamount:','Rs',finalamount)
            print(75*"-")
            print(50*" ","Thanks for visiting our store")
            print(75*"-")
# Out:
# Enter your name:Lalita
# for list of items press 11
# Rice Rs 50/kg
# Sugar            Rs 40/kg
# Salt             Rs 20/kg
# Dal              Rs 100/kg
# Coffee           Rs 1000/kg
# Tea              Rs 750/kg
# Groundnut Oil    Rs 150/litre
# Paneer           Rs 350/kg
# Boost            Rs 150/kg
# Ghee             Rs 350/kg
# Colgate          Rs 200/gms
#
# if you want to buy press1 or 2 to exit:1
# Enter your items:Rice
# Enter quantity:3
# Sorry the entered item is not available
# can i print you bill yes or no:no
# if you want to buy press1 or 2 to exit:1
# Enter your items:Sugar
# Enter quantity:2
# Sorry the entered item is not available
# can i print you bill yes or no:no
# if you want to buy press1 or 2 to exit:1
# Enter your items:Tea
# Enter quantity:2
# can i print you bill yes or no:yes
# ========================= More store =========================
#                              Hyderabad
# ...
